# %%
import pandas as pd
kk = pd.read_csv('kk.csv', index_col = 0)
kk

Ülke	Başkent	Yüzölçüm	Nüfus
TUR	Türkiye	Ankara	783562	83154997
BUL	Bulgaristan	Sofya	110994	7050034
YUN	Yunanistan	Atina	1319857	10856291
GUR	Gürcistan	Tiflis	69700	4483200
ERM	Ermenistan	Erivan	29743	3230100
IRN	İran	Tahran	1648195	82531700
IRK	Irak	Bağdat	437072	37056169
SUR	Suriye	Şam	185180	18507587

for değer in kk:
    print(değer)

Ülke
Başkent
Yüzölçüm
Nüfus

for etiket, satır in kk.iterrows():
    print(etiket)
    print(satır)

TUR
Ülke         Türkiye
Başkent       Ankara
Yüzölçüm      783562
Nüfus       83154997
Name: TUR, dtype: object
BUL
Ülke        Bulgaristan
Başkent           Sofya
Yüzölçüm         110994
Nüfus           7050034
Name: BUL, dtype: object
YUN
Ülke        Yunanistan
Başkent          Atina
Yüzölçüm       1319857
Nüfus         10856291
Name: YUN, dtype: object
GUR
Ülke        Gürcistan
Başkent        Tiflis
Yüzölçüm        69700
Nüfus         4483200
Name: GUR, dtype: object
ERM
Ülke        Ermenistan
Başkent         Erivan
Yüzölçüm         29743
Nüfus          3230100
Name: ERM, dtype: object
IRN
Ülke            İran
Başkent       Tahran
Yüzölçüm     1648195
Nüfus       82531700
Name: IRN, dtype: object
IRK
Ülke            Irak
Başkent       Bağdat
Yüzölçüm      437072
Nüfus       37056169
Name: IRK, dtype: object
SUR
Ülke          Suriye
Başkent          Şam
Yüzölçüm      185180
Nüfus       18507587
Name: SUR, dtype: object

for etiket, satır in kk.iterrows(): 
    print(etiket + " : " + satır["Başkent"])

TUR : Ankara
BUL : Sofya
YUN : Atina
GUR : Tiflis
ERM : Erivan
IRN : Tahran
IRK : Bağdat
SUR : Şam

for etiket, row in kk.iterrows():
    kk["Yoğunluk"] = kk["Yüzölçüm"] / kk["Nüfus"]
kk

Ülke	Başkent	Yüzölçüm	Nüfus	Yoğunluk
TUR	Türkiye	Ankara	783562	83154997	0.009423
BUL	Bulgaristan	Sofya	110994	7050034	0.015744
YUN	Yunanistan	Atina	1319857	10856291	0.121575
GUR	Gürcistan	Tiflis	69700	4483200	0.015547
ERM	Ermenistan	Erivan	29743	3230100	0.009208
IRN	İran	Tahran	1648195	82531700	0.019970
IRK	Irak	Bağdat	437072	37056169	0.011795
SUR	Suriye	Şam	185180	18507587	0.010006

for etiket, satır in kk.iterrows():
    kk.loc[etiket, "Harf_Sayısı"] = len(satır["Başkent"])
kk

Ülke	Başkent	Yüzölçüm	Nüfus	Yoğunluk	Harf_Sayısı
TUR	Türkiye	Ankara	783562	83154997	0.009423	6.0
BUL	Bulgaristan	Sofya	110994	7050034	0.015744	5.0
YUN	Yunanistan	Atina	1319857	10856291	0.121575	5.0
GUR	Gürcistan	Tiflis	69700	4483200	0.015547	6.0
ERM	Ermenistan	Erivan	29743	3230100	0.009208	6.0
IRN	İran	Tahran	1648195	82531700	0.019970	6.0
IRK	Irak	Bağdat	437072	37056169	0.011795	6.0
SUR	Suriye	Şam	185180	18507587	0.010006	3.0

kk["Ülke_Harf"] = kk["Ülke"].apply(len)
kk

Ülke	Başkent	Yüzölçüm	Nüfus	Yoğunluk	Harf_Sayısı	Ülke_Harf
TUR	Türkiye	Ankara	783562	83154997	0.009423	6.0	7
BUL	Bulgaristan	Sofya	110994	7050034	0.015744	5.0	11
YUN	Yunanistan	Atina	1319857	10856291	0.121575	5.0	10
GUR	Gürcistan	Tiflis	69700	4483200	0.015547	6.0	9
ERM	Ermenistan	Erivan	29743	3230100	0.009208	6.0	10
IRN	İran	Tahran	1648195	82531700	0.019970	6.0	4
IRK	Irak	Bağdat	437072	37056169	0.011795	6.0	4
SUR	Suriye	Şam	185180	18507587	0.010006	3.0	6

# %% [markdown]
# Soru 1 : **Aşağıda verilen bir veri çerçevesinde bulunan satırlar üzerinde iterasyon yapmak için yazılması gereken kod hangisidir?**
#
# import pandas as pdliste = pd.read_csv('liste.csv', index_col = 0)

# %%
#Cevap : for etiket, satır in liste.iterrows() :
#print(etiket)
#print(satır)

# %% [markdown]
# Soru 2 : **Bir satırdaki metin verisinde bulunan harflerin kaç tane olduğunu saydırmak için kullanılması gereken metot hangisidir?**

# %%
#Cevap : len()

# %% [markdown]
# Soru 3 : **Veri çerçevelerindeki her satır üzerinde iterasyon yapmakiçin kullaınlması gereken metot hangisidir?**

# %%
#Cevap : itterorws()
