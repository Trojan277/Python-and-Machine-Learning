# %% [markdown]
# **Ortalama** veya merkezsel konum olculeri, istatiksik bilim dalinda ve ver analizinde kullanilan bir veri dizisinin **orta konumunu**, tek bir sayi ile ifade eden betimsel istatistik olcusudur.

# %% [markdown]
# **Ortanca** bir anakutle ya da orneklem veri serisini kucukten buyuge dogru siraladigimizda, **seriyi ortadan ikiye ayiran degere denir.** Istatistigin bir alt dali olan betimsel istatistikte medyan bir merkezsel konum olcusu kabul edilir.

# %% [markdown]
# ![Adsiz.png](attachment:Adsiz.png)

# %% [markdown]
# ![Ads%C4%B1z.png](attachment:Ads%C4%B1z.png)

# %%
import numpy as np
np.mean(data2['dem_share'])

# %% [markdown]
# 27.61103448275862

# %%
np.median(data2['dem_share'])

# %% [markdown]
# 22.47

# %% [markdown]
# Soru 1 : **Bir veri setinin ortalaması, veri setinde yer alan çok yüksek ve çok düşük değerlerden etkilenir.**

# %%
#Cevap : Dogru

# %% [markdown]
# Soru 2 : **Ortanca, bir veri setinin %25 ile %75 lik dilimleri arasında kalan değerlerin ortalamasıdır.**

# %%
#Cevap : Yanlis

# %% [markdown]
# Soru 3 : **Ortalama ve ortanca hesaplaması için kullanılması gereken fonksiyon hangisidir?**

# %%
#Cevap : 
# np.mean
# np.median
