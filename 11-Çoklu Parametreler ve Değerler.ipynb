# %%
def us (sayi1, sayi2):
    """Bir sayinin verilen ussunu almak"""
    sayi3 = sayi1 ** sayi2
    return sayi3
sonuc = us(7,3)
print (sonuc)
# Out:
# 343

# %%
rakam = (1,2,3)
type(rakam)
# Out:
# tuple

# %%
x,y,z = rakam
print(x)
# Out:
# 1

# %%
rakam[0]
# Out:
# 1

# %%
def us2 (sayi1, sayi2):
    """Bir sayinin verilen ussunu almak ve sayilarin yerini degistirerek ayni islemi tekrar yapmak"""
    sayi3 = sayi1 ** sayi2
    sayi4 = sayi2 ** sayi1
    
    demet = (sayi3, sayi4)
    
    return demet
sonuclar = us2(7,3)
print(sonuclar)
# Out:
# (343, 2187)

# %% [markdown]
# Soru 1 : **Birden fazla parametrenin bulunduğu fonksiyonlarda elde edilen değerlerin yazdırıldığı veri tipi hangisidir?**

# %%
#Cevap : Demet(Tuple)

# %% [markdown]
# Soru 2 : **Herhangi bir sayının karesini alan fonksiyon hangisidir?**

# %% [markdown]
# ![asdadsdad.png](attachment:asdadsdad.png)

# %% [markdown]
# Cevap :
# ![asdasd1111.png](attachment:asdasd1111.png)

# %% [markdown]
# Soru 3 : **Fonksiyonlarda parametrelerin bulunduğu satır hangi seçenekte doğru gösterilmiştir?**

# %% [markdown]
# ![dfdfd.png](attachment:dfdfd.png)

# %% [markdown]
# Cevap :
# ![sfsdds123.png](attachment:sfsdds123.png)
