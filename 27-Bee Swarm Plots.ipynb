# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('2008_swing_states.csv')

plt.hist(data['dem_share']) # Histogram olusturma
plt.xlabel('Demokrat Oy Orani') # x ekseni basligi
plt.ylabel('Ilce') # y ekseni basligi
plt.title('Demokratlarin Swing States Oylari (2008 Secimleri)')
plt.show()

# %% [markdown]
# ![Untitled%20%283%29.png](attachment:Untitled%20%283%29.png)

# %%
sorted(data)

# %% [markdown]
# ['county', 'dem_share', 'dem_votes', 'rep_votes', 'state', 'total_votes']

# %%
import seaborn as sns 
sns.set()

sns.swarmplot(x= 'state', y= 'dem_share', data = data)
plt.xlabel('Eyaletler')
plt.ylabel('Demokrat oy Orani')
plt.title('Demokratlarin Swing States Oylari (2008 Secimleri)')
plt.show()

# %% [markdown]
# ![Untitled%20%284%29.png](attachment:Untitled%20%284%29.png)

# %% [markdown]
# Soru 1 : **Swarm plot ve histogram arasındaki en belirgin fark nedir?**

# %%
#Cevap : Tum verilerin grafik uzerinde gosterilebilmesi

# %% [markdown]
# Soru 2 : **Aşağıda verilen kod bloğunda eksik yere hangisi getirilmelidir?**

# %%
import seaborn as sns
sns.set()
sns.swarmplot(x = 'Sütun1',y = 'Sütun2', ___ = bilgiler)

# %%
#Cevap : data

# %% [markdown]
# Soru 3 : **Swarm plotlarda verilerin x eksenindeki dağılım aralığı neyi ifade eder?**

# %%
#Cevap : Y eksenin belirtilen degerde bulunan verilerin sayisi
