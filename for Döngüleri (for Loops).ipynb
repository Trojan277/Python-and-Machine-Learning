# %%
kilo = [87,23,68,14,152]

#for var in seq:
#    expression

#for HerDeğişken in liste/Dizi
#    Yapılacakİşlem

for kişi in kilo:
    print(kişi)
87
23
68
14
152

kilo = [87,23,68,14,152]

for index, kişi in enumerate(kilo):
    print("index" + str(index) + ":" + str(kişi))

index0:87
index1:23
index2:68
index3:14
index4:152

for harf in "türkiye":
    print(harf.capitalize())
T
Ü
R
K
İ
Y
E

# %% [markdown]
# Soru 1 : Aşağıdaki döngünün çıktısı nedir?

# %%
yaş = [11,12,13,14,15]
for kişi in yaş:
    print(kişi)

# %%
#Cevap : 
11
12
13
14
15

# %% [markdown]
# Soru 2 : **Loop döngüsü listede bulunan elemanlardan sadece ilki için geçerlidir.**

# %%
#Cevap : Yanlis

# %% [markdown]
# Soru 3 : **Loop dongusu icin enumerate kullanimi hangi secenekte dogru verilmistir?**
# ![soru.png](attachment:soru.png)

# %%
#Cevap :
#   alan = [13.25, 28.0, 20.0, 9.75, 29.50]
#   for index, alan in enumerate(alan) :
#       print('Alan', str(index+1),':', str(index))
