# %% [markdown]
# - Dogruluk ( Accuracy )
#     - Dogru tahmin edilen veri / Toplam veri
#     - Her zaman beklentiyi karsilamaz
#     - Daha detayli metrikleri ihtiyac var
# - Hassasiyet ( Precision )
# - Geri Cagirma ( Recall )
# - F1 Degeri ( F1 score )

# %% [markdown]
# ![tbloo.png](attachment:tbloo.png)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pandas as pd

data = pd.read_csv('diabetes.csv')

# %%
type(data)

# %% [markdown]
# pandas.core.frame.DataFrame

# %%
data.head()

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
X = data.drop(['Outcome'], axis = 1)
type(X)
X.head()

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
y = data['Outcome']
print(y)

# %% [raw]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
knn = KNeighborsClassifier(n_neighbors = 6)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 100)
knn.fit(X_train, y_train)
y_prediction = knn.predict(X_test)

# %%
print(confusion_matrix(y_test, y_prediction))

# %% [raw]
# [[143  20]
#  [ 49  42]]

# %%
print(classification_report(y_test, y_prediction))

# %% [raw]
#               precision    recall  f1-score   support
#
#            0       0.74      0.88      0.81       163
#            1       0.68      0.46      0.55        91
#
#     accuracy                           0.73       254
#    macro avg       0.71      0.67      0.68       254
# weighted avg       0.72      0.73      0.71       254

# %% [markdown]
# Soru 1: **confusion_matrix ve classification_matrix nereden import edilir?**

# %%
#Cevap : from sklearn.metrics

# %% [markdown]
# Soru 2: **confusion_matrix için girdi parametreleri hangi seçenekte doğru verilmiştir?**

# %%
#Cevap : tes_verisi, tahmin_edilen_veri

# %% [markdown]
# Soru 3: **Tüm pozitif sınıflardan ne kadar doğru tahmin edildiğini tanımlayan parametre hangisidir?**

# %%
#Cevap : Recall (Geri Cagirma)
